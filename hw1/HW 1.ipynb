# %% [markdown]
# # Homework 1:
# Broderick Higby
# A14247031
#
# ## Question 1: Matrix Calculus
# - $f(x) = λ(1−{a}^{T}x)$, where λ is a constant, derive ∂f(x). ∂x
#     - Answer: -$\lambda a$
# - $f(x) = λ(1−{x}^{T}Ax)$ where A is a symmetric matrix and λ is a constant, derive ∂f(x). ∂x
#     - Answer: $-2 \lambda Ax$

# %% [markdown]
# ## Question 2: One-hot Encoding
# Represent the dataset S using a matrix and show how your one-hot encoding is derived.

# %%
import numpy as np
car_dataset_labels = ["Length (inch)","Height (inch)", "Toyota","BMW","Ford",
                      "Blue","Silver","Red","Black"]
S = [[183, 62, 1, 0, 0, 1, 0, 0, 0],
     [181, 65, 0, 1, 0, 0, 1, 0, 0],
     [182, 59, 0, 1, 0, 0, 0, 1, 0],
     [179, 68, 0, 0, 1, 1, 0, 0, 0],
     [182, 53, 1, 0, 0, 0, 0, 0, 1]]
print(np.append(car_dataset_labels,S))
# Out:
# ['Length (inch)' 'Height (inch)' 'Toyota' 'BMW' 'Ford' 'Blue' 'Silver'
#  'Red' 'Black' '183' '62' '1' '0' '0' '1' '0' '0' '0' '181' '65' '0' '1'
#  '0' '0' '1' '0' '0' '182' '59' '0' '1' '0' '0' '0' '1' '0' '179' '68' '0'
#  '0' '1' '1' '0' '0' '0' '182' '53' '1' '0' '0' '0' '0' '0' '1']

# %% [markdown]
# ## Question 3: Basic Matrix Operations Using NumPy
# 1. A+B
# 2. A ◦ B (’◦’ operator means element-wise product or Hadamard product)
# 3. A$^{T}$B
# 4. AB$^{T}$
# 5. AB

# %%
import numpy as np
np.set_printoptions(suppress=True)
A = np.array([[1,2], [3,4], [5,6]])
B = np.array([[1,-1], [-1,1],[1,-1]])

# %% [markdown]
# A+B

# %%
print(A+B)
# Out:
# [[2 1]
#  [2 5]
#  [6 5]]

# %% [markdown]
# A ◦ B (’◦’ operator means element-wise product or Hadamard product)

# %%
print(np.multiply(A,B))
# Out:
# [[ 1 -2]
#  [-3  4]
#  [ 5 -6]]

# %% [markdown]
# A$^{T}$B

# %%
print(np.dot(A.transpose(),B))
# Out:
# [[ 3 -3]
#  [ 4 -4]]

# %% [markdown]
# AB$^{T}$

# %%
print(np.dot(A,B.transpose()))
# Out:
# [[-1  1 -1]
#  [-1  1 -1]
#  [-1  1 -1]]

# %% [markdown]
# AB
#     - Answer: Impossible: The matricies are not the correct dimensions

# %% [markdown]
# ## Question 4: Basic Plots using Matplotlib

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 
np.random.seed(0)
space = np.linspace(0, 10, num = 50) 
sine = np.sin(space)
sine_5 = sine
for i in range(5):
    sine_5 = sine_5 + np.random.normal(scale = 0.1, size = 50)
plt.scatter(space, sine, color = 'b', label = 'sine_curve')
plt.plot(space, sine_5, color = 'r', label = 'noise_5_iters')
plt.legend(loc = 'upper right')
plt.title("5 Iterations of Gaussian Noise")
plt.savefig('./Q4.png')
plt.show()

# %%
np.random.seed(0)
space = np.linspace(0, 10, num = 50) 
sine = np.sin(space)
sine_20 = sine
for i in range(20): # Apply Gaussian noise (0 mean & 0.1 StdDev)
    sine_20 = sine_20 + np.random.normal(scale = 0.1, size = 50)
# Visualize the plot
plt.scatter(space, sine, color = 'b', label = 'sine_curve')
plt.plot(space, sine_20, color = 'r', label = 'noise_20_iters')
plt.legend(loc = 'upper right')
plt.title("20 Iterations of Gaussian Noise")
plt.savefig('./Q4.png')
plt.show()

# %%
np.random.seed(0)
space = np.linspace(0, 10, num = 50) 
sine = np.sin(space)
sine_100 = sine
for i in range(100):
    sine_100 = sine_100 + np.random.normal(scale = 0.1, size = 50)
plt.scatter(space, sine, color = 'b', label = 'sine_curve')
plt.plot(space, sine_100, color = 'r', label = 'noise_100_iters')
plt.legend(loc = 'upper right')
plt.title("100 Iterations of Gaussian Noise")
plt.savefig('./Q4.png')
plt.show()

# %% [markdown]
# ## Question 5: Basic Image Operations using Matplotlib

# %%
import matplotlib.pyplot as plt
img = plt.imread('cat.jpg') # The img here is a NumPy array. 
plt.imshow(img)
plt.show()

# %% [markdown]
# What is the shape of the image array?

# %%
img.shape
# Out:
# (183, 275, 3)

# %% [markdown]
# ## Question 6: Data And Visualization
# Show the first 2 and 3 feature dimensions (seperately).

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

iris = datasets.load_iris()
X = iris.data
y = iris.target

plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1,
            edgecolor='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title("First two feature dimenstions")
plt.show()


# # To get a better understanding of interaction of the dimensions
# # plot the first three PCA dimensions

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_title("First 3 Feature Dimensions")
ax.set_xlabel("Sepal Length")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("Sepal Width")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("Petal Length")
ax.w_zaxis.set_ticklabels([])
# ax.invert_zaxis()
plt.show()

# %% [markdown]
# ## Question 7: Data Manipulation
# 7.1. Show the first 3 features of the first 5 datapoints of array x

# %%
print(X[0:5,0:3])
# Out:
# [[ 5.1  3.5  1.4]
#  [ 4.9  3.   1.4]
#  [ 4.7  3.2  1.3]
#  [ 4.6  3.1  1.5]
#  [ 5.   3.6  1.4]]

# %% [markdown]
# 7.2 - Calculate the mean and the variance of the 3rd feature (the 3rd column) of array X.

# %%
print("Mean: ", np.mean(X[:,2]))
print("Variance: ", np.var(X[:,2]))
# Out:
# Mean:  3.75866666667
# Variance:  3.09242488889

# %% [markdown]
# 7.3
# - Perform a linear projection on all 4 features (columns) using the weight vector `w=(1,2,3,4)`. You can do so by calculating a dot product between the 4 features of all data points and the weight vector w. The shape of projected data points should be (150, 1) or (150,), depending on if the weight vector is regarded as a matrix or a vector.
# - Calculate the mean of the projected data points.
# (hint: You can calculate the projection with a single line code using np.dot, but you should be careful with the dimension matching for the dot product)

# %%
w = (1,2,3,4)
projectedX = np.dot(X,w)
print(np.mean(projectedX))
projectedX.shape
# Out:
# 28.022
# (150,)

# %% [markdown]
# 7.4 - Randomly sample 4 data points (rows) of array X by randomly choosing the row indices. Show the indices and the sampled data points.

# %%
import random
for i in range(0,4):
    print(X[random.randint(0,149)])
    i+=1
# Out:
# [ 7.2  3.2  6.   1.8]
# [ 6.7  2.5  5.8  1.8]
# [ 6.3  3.3  4.7  1.6]
# [ 7.4  2.8  6.1  1.9]

# %% [markdown]
# 7.5 - Add one more feature (one more column) to the array X after the last feature. The values of the added feature for all data points are constant 1. Show the first data point (first row) of the new array.

# %%
X = np.c_[X,np.ones((150,1))]
print(X[0])
# Out:
# [ 5.1  3.5  1.4  0.2  1. ]

# %% [markdown]
# 7.6 - Add one more data point (one more row) to the array X after the last data point. The value of the added data point is the same as the first data point. Show the first feature (first column) of the new array.

# %%
firstRowofX = X[0,:]
X = np.vstack([X, firstRowofX])
print(X[:, 0])
# Out:
# [ 5.1  4.9  4.7  4.6  5.   5.4  4.6  5.   4.4  4.9  5.4  4.8  4.8  4.3  5.8
#   5.7  5.4  5.1  5.7  5.1  5.4  5.1  4.6  5.1  4.8  5.   5.   5.2  5.2  4.7
#   4.8  5.4  5.2  5.5  4.9  5.   5.5  4.9  4.4  5.1  5.   4.5  4.4  5.   5.1
#   4.8  5.1  4.6  5.3  5.   7.   6.4  6.9  5.5  6.5  5.7  6.3  4.9  6.6  5.2
#   5.   5.9  6.   6.1  5.6  6.7  5.6  5.8  6.2  5.6  5.9  6.1  6.3  6.1  6.4
#   6.6  6.8  6.7  6.   5.7  5.5  5.5  5.8  6.   5.4  6.   6.7  6.3  5.6  5.5
#   5.5  6.1  5.8  5.   5.6  5.7  5.7  6.2  5.1  5.7  6.3  5.8  7.1  6.3  6.5
#   7.6  4.9  7.3  6.7  7.2  6.5  6.4  6.8  5.7  5.8  6.4  6.5  7.7  7.7  6.
#   6.9  5.6  7.7  6.3  6.7  7.2  6.2  6.1  6.4  7.2  7.4  7.9  6.4  6.3  6.1
#   7.7  6.3  6.4  6.   6.9  6.7  6.9  5.8  6.8  6.7  6.7  6.3  6.5  6.2  5.9
#   5.1]
